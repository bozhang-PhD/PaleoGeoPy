# %% [markdown]
# ### Required libraries

# %%
import numpy as np
import pygplates as pgp
import os
import pandas as pd

# %% [markdown]
# ### Import data

# %%
# Load Torsvik_2012 poles
pmag_file = '/Users/Mike/PhD/Palaeomagnetic_data/Torsvik_2012/publication_table/torsviketal2012_utf8.csv'
pmag_data = pd.read_csv(pmag_file)

# Load polygon file
#polyFile = "/Users/Mike/PhD/Plate_Polygons/Global_Cookie_Cut_Coastlines_2014_v2_GPlates1_4.gpml"

# test coastline sets
polyFile = "/Users/Mike/PhD/Plate_Models/Wright_et_al_2013/Phanerozoic_EarthByte_Coastlines.gpmlz"
#polyFile = "/Users/Mike/PhD/Plate_Models/Li_2008_Rodinia/RodiniaBlocks_v1p1_Coastlines.shp"
#polyFile = "/Users/Mike/PhD/Plate_Models/Deforming_model_2014.1/Global_Model_WD_Internal_Release_2014.1/StaticGeometries/Global_EarthByte_GeeK07_Coastlines_2014.1.gpmlz"
#polyFile = "/Users/Mike/Projects/Nordic_Supercontinent_Workshop/NUNA_poly_rot/Nuna_elements.gpml"
#polyFile = "/Users/Mike/PhD/Plate_Models/Shephard_etal_2013_ESR/GPlates/Shephard_etal_ESR2013_Global_Coastlines_cookiecuttostatic.gpml"
#polyFile = "/Applications/GPlates-1.4.0/SampleData/FeatureCollections/Coastlines/Seton_etal_ESR2012_Coastlines_2012.1_Polygon.gpmlz"

# %%
# Iterate through palaeomagnetic pole dataset (pmag_data) and build lists of unique terranes and continental blocks
terrane_list = []
block_list = []

for i, terrane in enumerate(pmag_data.Terrane.values):
    
    if terrane not in terrane_list:
        
        terrane_list.append(pmag_data.Terrane[i])
        
        
for j, block in enumerate(pmag_data.Block.values):
    
    if block not in block_list:
        
        block_list.append(pmag_data.Block[j])
        
#######

# Iterate through palaeomagnetic pole data set and build Pandas DataFrame of required data
pole_list = []

for terrane in terrane_list:
    
    for k, item in enumerate(pmag_data.Terrane.values):
        
        if item == terrane:
            
            # Create dictionary for DataFrame
            pole_list.append({'Terrane': pmag_data.Terrane[k], 'Block': pmag_data.Block[k], 'Formation': pmag_data.Formation[k], 
                              'PLat': pmag_data.PLat[k], 'PLon': pmag_data.PLon[k], 'CPlat': pmag_data.CLat[k],
                              'CPlon':pmag_data.CLon[k], 'SLat': pmag_data.SLat[k],'SLon': pmag_data.SLon[k], 
                              'AgeNominal': pmag_data.AgeNominal[k], 'AgeLower': pmag_data.AgeLower[k], 
                              'AgeUpper': pmag_data.AgeUpper[k], 'a95': pmag_data.a95[k], 'N': pmag_data.N[k],
                              'k': pmag_data.k[k], 'Dec': pmag_data.Dec[k], 'Inc': pmag_data.Inc[k], 'Q': pmag_data.Q[k]})
            
# Create and display Pandas DataFrame   
raw_polesDF = pd.DataFrame(pole_list)
raw_polesDF
# Out:
#      AgeLower  AgeNominal  AgeUpper            Block  CPlat  CPlon     Dec  \
# 0         0.0         0.5       1.0    North America    NaN    NaN  176.10
# 1         0.0         0.8       1.0    North America    NaN    NaN  356.40
# 2         0.0         1.0       1.5    North America    NaN    NaN  359.20
# 3         0.0         1.0       3.0    North America    NaN    NaN  183.40
# 4         0.0         1.0       3.0    North America    NaN    NaN  359.50
# 5         0.0         1.5       3.0    North America  -80.0    3.5  337.20
# 6         0.0         1.5       3.0    North America  -81.2   73.9   13.00
# 7         1.0         1.5       3.0    North America    NaN    NaN  180.10
# 8         1.0         3.0       4.0    North America    NaN    NaN    0.40
# 9         2.5         4.0       5.0    North America    NaN    NaN  354.60
# 10        1.5         4.0       7.5    North America    NaN    NaN  359.50
# 11        0.0         5.0       6.0    North America    NaN    NaN    4.40
# 12        3.5         7.0       7.0    North America    NaN    NaN  178.10
# 13        5.0         8.0      11.0    North America    NaN    NaN  355.60
# 14        7.0        10.0      10.0    North America    NaN    NaN  172.17
# 15       14.0        15.5      17.0    North America  -83.1   93.2    4.50
# 16       20.5        21.0      22.5    North America    NaN    NaN  351.10
# 17       18.9        21.7      24.4    North America    NaN    NaN  348.80
# 18       22.0        22.5      24.0    North America    NaN    NaN    3.10
# 19       22.0        23.0      24.0    North America    NaN    NaN  166.20
# 20       21.0        23.5      26.0    North America    NaN    NaN  349.10
# 21       23.0        26.0      29.0    North America    NaN    NaN  347.20
# 22       26.0        27.0      28.0    North America    NaN    NaN  350.00
# 23       24.0        30.0      36.0    North America    NaN    NaN  172.50
# 24       23.0        30.0      36.0    North America    NaN    NaN  171.00
# 25       32.0        33.0      34.0    North America    NaN    NaN  351.00
# 26       35.0        37.0      39.0    North America    NaN    NaN  348.60
# 27       36.0        38.5      41.0    North America    NaN    NaN  343.70
# 28       34.0        40.0      42.0    North America    NaN    NaN  179.90
# 29       41.0        42.0      43.0    North America    NaN    NaN  158.80
# ..        ...         ...       ...              ...    ...    ...     ...
# 564     479.0       495.0     495.0        Australia    NaN    NaN  274.50
# 565     482.0       500.0     502.0        Australia    NaN    NaN  231.10
# 566     501.0       510.0     520.0        Australia    NaN    NaN  250.70
# 567     501.0       510.0     513.0        Australia  -31.3   26.7  232.30
# 568     501.0       510.0     513.0        Australia    NaN    NaN  227.50
# 569     513.0       515.0     525.0        Australia  -32.8   13.9  224.50
# 570     513.0       522.0     542.0        Australia    NaN    NaN   19.30
# 571     506.0       523.0     528.0        Australia    NaN    NaN  224.10
# 572     501.0       525.0     542.0        Australia  -28.7    5.7  227.20
# 573     530.0       534.0     560.0        Australia  -37.4  331.7   16.20
# 574     528.0       535.0     542.0        Australia    NaN    NaN  233.40
# 575     550.0       550.0     610.0        Australia  -20.2  326.5  189.00
# 576       NaN         1.0       NaN  East Antarctica    NaN    NaN     NaN
# 577       0.0         2.0       4.0  East Antarctica    NaN    NaN    7.60
# 578       NaN         5.0       NaN  East Antarctica    NaN    NaN     NaN
# 579       NaN        27.0       NaN  East Antarctica    NaN    NaN     NaN
# 580     152.0       164.0     176.0  East Antarctica    NaN    NaN   29.30
# 581     175.0       183.0     183.0  East Antarctica    NaN    NaN  261.40
# 582     175.0       183.0     183.0  East Antarctica    NaN    NaN  263.00
# 583     175.0       183.0     183.0  East Antarctica    NaN    NaN  237.60
# 584     175.0       183.0     183.0  East Antarctica    NaN    NaN  246.50
# 585     176.0       193.0     200.0  East Antarctica    NaN    NaN  252.70
# 586     160.0       195.0     230.0  East Antarctica    NaN    NaN   50.90
# 587     463.0       471.5     480.0  East Antarctica    NaN    NaN  222.40
# 588       NaN       475.0       NaN  East Antarctica    NaN    NaN     NaN
# 589     475.0       479.0     483.0  East Antarctica    NaN    NaN  217.60
# 590     477.0       484.0     491.0  East Antarctica    NaN    NaN  222.60
# 591       NaN       499.0       NaN  East Antarctica    NaN    NaN     NaN
# 592     457.0       500.0     543.0  East Antarctica    NaN    NaN  216.70
# 593     482.0       515.0     515.0  East Antarctica    NaN    NaN  341.50
#
#                                              Formation   Inc    N  PLat  \
# 0                      USGS SW North America composite -57.7  108 -86.3
# 1                  Michoacan Guanajuato volcanic field  39.5   64 -86.4
# 2                              Tequila volcanic fields  29.6   17 -85.8
# 3                             Meseta Lago Buenos Aires -63.0  274 -88.4
# 4                          Trans Mexican Volcanic Belt  33.6   24 -88.9
# 5                            Katherine Creek sediments  73.3  100 -77.9
# 6                                Banks Island deposits  81.0  418 -85.7
# 7                      USGS SW North America composite -50.0  150 -84.5
# 8                          Trans-Mexican Volcanic Belt  34.3   14 -89.2
# 9                          Trans Mexican Volcanic Belt  33.7   50 -84.6
# 10                           Eastern Alkaline Province  32.9   17 -87.9
# 11                                   Snake River Plain  59.2   23 -86.9
# 12                     USGS SW North America composite -51.2  133 -85.3
# 13                         Trans Mexican Volcanic Belt  37.4   22 -85.9
# 14                     USGS SW North America composite -52.7  269 -82.9
# 15                            Hepburn's Mesa Formation  56.4  144 -81.1
# 16                         Stoddard Mountain laccolith  57.8   19 -82.9
# 17                                     Dinan Bay lavas  68.1   13 -83.3
# 18                                     Younger plutons  55.0   78 -87.1
# 19                                   Lake City Caldera -65.3  128 -76.4
# 20                         Latir intrusives, volcanics  53.7  297 -80.8
# 21                      Conejos and Hinsdale Formation  55.6  168 -79.7
# 22                         Latir extrusives, sediments  50.8  423 -80.2
# 23                           Mongollon-Datil volcanics -49.0  279 -82.8
# 24                           Mongollon-Datil volcanics -47.3  595 -81.9
# 25                           Tuzantl-n-Copalillo basin  39.9    9 -80.6
# 26                            Mariscal Mountain Gabbro  50.9  144 -79.8
# 27                                 Ramsay Island lavas  65.0   11 -78.1
# 28                               Mistastin Lake Impact -68.2   73 -85.2
# 29                        Beaver River alkalic complex -73.1   21 -79.2
# ..                                                 ...   ...  ...   ...
# 564  Chatswood limestone and Ninmaroo Formation, We...   4.3   64   3.1
# 565                 Black Hill Norite, South Australia -37.5   22 -37.5
# 566              Hugh River shale, Jay Creek limestone   8.3  110 -19.3
# 567  Lake Frome Group Combined, Flinders Ranges, So...  -0.5   80 -31.4
# 568    Giles Creek dolomite, Ross River, Amadeus Basin   0.3   33 -38.3
# 569  Cambrian sediments, Kangaroo Island, South Aus...  -4.4   77 -33.8
# 570            Todd River dolomite, Northern Territory  35.0   34 -43.2
# 571  Billy Creek Formation, Aroona Creek and Wirrea...  -1.2   78 -37.4
# 572    Pertaoorta Group, Areyonga Gorge, Amadeus Basin -19.4  136 -32.7
# 573       Upper Arumbera sandstone, Northern Territory  31.2   57 -46.6
# 574     Hawker Group, Flinders Ranges, South Australia -27.8   89 -21.3
# 575  Brachina Formation, Adelaide Geosyncline, Sout... -44.0   24 -33.0
# 576                            McMurdo Sound volcanics   NaN  NaN -85.5
# 577                         McMurdo volcanics combined -85.1  450 -87.3
# 578                        James Ross Island volcanics   NaN  NaN -86.4
# 579                Kerguelen islands (Antarctic Plate)   NaN  NaN -85.5
# 580                        Lavas and dykes, Vestfjella -57.2  105 -51.4
# 581  Ferrar dolerites, Northern Prince Albert Mount... -68.8  227 -47.8
# 582               Ferrar dolerite sill, Mount Cerberus -74.8    9 -57.8
# 583                    Ferrar dolerites, Wright Valley -69.4   26 -45.3
# 584                     Ferrar dolerite, McMurdo Sound -72.1   64 -50.5
# 585            Storm Peak Lavas, Queen Alexandra Range -64.2   72 -44.1
# 586                         Vestfjella lavas and dykes -52.0  142 -41.8
# 587      Vanda lamprophyre and porphyry, Wright Valley -13.2   58  -2.5
# 588                     South Victoria Land intrusives   NaN  NaN  -3.5
# 589                       Teall Nunatak, Victoria Land  -2.7   58 -11.0
# 590                   Lamprophyre dykes, Taylor Valley   0.6   16  -9.3
# 591                             Killer Ridge/Mount Lok   NaN  NaN  -7.0
# 592                      Granitic rocks, Wright Valley  -9.0   16  -5.4
# 593            Sor Rondane intrusives, Queen Maud Land  64.0   16 -28.5
#
#       PLon  Q  SLat   SLon        Terrane   a95      k
# 0      5.7  5  36.3  242.0      Laurussia   4.8    NaN
# 1      8.4  5  21.0  255.0      Laurussia   9.1   29.0
# 2    264.3  5  20.5  256.5      Laurussia   6.9   27.5
# 3    225.5  5  47.0  289.0      Laurussia   5.4    NaN
# 4    285.0  5  19.4  260.1      Laurussia   4.3   47.3
# 5    303.7  3  65.0  232.4      Laurussia   4.9    9.1
# 6    122.7  3  71.0  238.0      Laurussia   7.0   21.0
# 7    241.0  5  36.3  242.0      Laurussia   5.7    NaN
# 8    214.8  5  19.2  260.7      Laurussia   5.2   59.0
# 9    332.3  5  20.1  259.4      Laurussia   4.1   25.6
# 10   275.9  5  20.0  263.0      Laurussia   6.7   30.0
# 11   187.8  5  43.0  246.5      Laurussia   5.0   38.2
# 12   262.1  5  36.3  242.0      Laurussia   5.0    NaN
# 13   357.7  5  20.4  259.7      Laurussia   6.9   21.0
# 14   309.1  5  36.3  242.0      Laurussia   7.8    NaN
# 15   225.3  3  45.3  249.2      Laurussia  12.9   51.9
# 16   346.2  5  37.6  246.6      Laurussia   3.7   82.2
# 17   317.8  5  53.7  227.3      Laurussia   9.8   19.0
# 18   189.5  4  36.6  254.5      Laurussia   6.7   46.9
# 19    30.3  3  38.0  252.7      Laurussia   8.4   19.2
# 20   331.7  4  36.8  254.6      Laurussia   5.2   18.2
# 21   342.8  4  37.2  254.4      Laurussia   6.8   21.0
# 22   315.4  4  36.8  254.6      Laurussia   5.4   13.1
# 23   316.2  3  33.3  252.2      Laurussia   5.0   22.3
# 24   323.6  4  33.3  252.1      Laurussia   4.4   18.1
# 25    22.1  6  18.0  260.7      Laurussia   6.2   70.4
# 26     5.9  4  29.1  256.8      Laurussia   4.3   65.1
# 27   299.9  5  52.5  228.7      Laurussia   7.0   41.0
# 28   296.6  3  55.9  296.6      Laurussia   2.4    NaN
# 29   325.8  6  60.2  235.0      Laurussia   3.0  116.8
# ..     ... ..   ...    ...            ...   ...    ...
# 564   54.1  6 -22.6  140.3  East Gondwana   7.4    6.7
# 565   34.4  3 -34.5  139.4  East Gondwana   3.8   67.5
# 566   39.1  6 -23.8  133.1  East Gondwana  10.0    NaN
# 567   26.9  3 -31.2  138.9  East Gondwana  10.1   16.6
# 568   24.5  3 -23.6  134.5  East Gondwana  10.4   38.5
# 569   15.1  3 -35.6  137.6  East Gondwana  12.3    9.4
# 570  339.9  7 -23.5  133.4  East Gondwana   6.7   14.7
# 571   20.1  6 -31.1  138.7  East Gondwana  14.4   11.0
# 572   11.5  6 -24.1  132.3  East Gondwana   7.3   84.5
# 573  337.3  6 -23.4  133.4  East Gondwana   4.1   22.6
# 574   14.9  5 -31.2  138.6  East Gondwana  11.4   12.3
# 575  328.0  6 -30.5  139.0  East Gondwana  16.0   13.5
# 576  143.6  5   NaN    NaN  East Gondwana   4.0    NaN
# 577  137.3  5 -78.0  165.4  East Gondwana   6.3    NaN
# 578   28.5  5   NaN    NaN  East Gondwana   7.0    NaN
# 579    9.3  5   NaN    NaN  East Gondwana   2.3    NaN
# 580  203.4  5 -73.7  345.1  East Gondwana   4.4   38.6
# 581  225.5  4 -74.5  162.0  East Gondwana   3.4  123.8
# 582  224.3  3 -77.4  161.8  East Gondwana   3.3  245.2
# 583  208.0  5 -77.5  161.6  East Gondwana   2.4    NaN
# 584  211.4  5 -77.2  160.0  East Gondwana  10.2   82.1
# 585  231.5  4 -84.0  165.0  East Gondwana   6.9    NaN
# 586  226.5  5 -73.3  345.0  East Gondwana   3.8   46.6
# 587   23.8  5 -77.5  161.6  East Gondwana   5.2    NaN
# 588   22.7  5   NaN    NaN  East Gondwana   7.6    NaN
# 589   21.0  5 -74.9  162.8  East Gondwana   7.2  163.0
# 590   26.7  4 -77.6  163.4  East Gondwana  10.9    NaN
# 591   21.4  4   NaN    NaN  East Gondwana  12.0    NaN
# 592   18.5  4 -77.5  161.6  East Gondwana   8.1    NaN
# 593    9.5  3 -72.0   24.0  East Gondwana   4.5    NaN
#
# [594 rows x 18 columns]

# %% [markdown]
# ### Perform 'point in polygon' test to assign plate ID to pole based on sampling location

# %%
featureCollection = pgp.FeatureCollectionFileFormatRegistry()
featureSet = featureCollection.read(polyFile)
 
try:
    featureSet = featureCollection.read(polyFile)

except pgp.OpenFileForReadingError:
    print "Doesn't work like that silly."


plateIDs = []
plates = []


# Array to contain correct line numbers from full dataset to make sure the correct values are assiciated the correct poles.
line = []
count = 0
polyCount = 0

for i in xrange(0, len(raw_polesDF)):
    
    count = count + 1
    
    if pd.isnull(raw_polesDF.SLat[i]) == False:
        inputlatLon = pgp.LatLonPoint(raw_polesDF.SLat[i], raw_polesDF.SLon[i])
        latLonPoint = pgp.convert_lat_lon_point_to_point_on_sphere(inputlatLon)
        
    for feature in featureSet:
        for property in feature:
            propertyName = property.get_name()
            
        
            if propertyName.get_name() == "unclassifiedGeometry":
            #if propertyName.get_name() == "outlineOf":
        
                polygons = property.get_value().get_polygon()
                #print polygons

                isPoly = polygons.is_point_in_polygon(latLonPoint)
                #print isPoly

                if isPoly == True:
                    
                    if feature.get_reconstruction_plate_id() != 346:
                        
                        plateIDs.append(feature.get_reconstruction_plate_id())
                        plates.append(feature.get_name())
                        line.append(i)
                    
                    # Uncomment this line for verbose output
                    # print "Count: " + str(count) + ", Line: " + str(line[polyCount]) + ", Value: " + str(raw_polesDF.a95[i]) + \
                    # ", PlateID: " + str(plateIDs[polyCount]) + ", Plate: " + str(plates[polyCount])

                    polyCount = polyCount + 1

print "Polygon test complete. Located and assigned plate ID's to", len(plateIDs), "poles."
# Out:
# Polygon test complete. Located and assigned plate ID's to 550 poles.

# %% [markdown]
# ### Create and populate FeatureCollection

# %%
# Loop through list of poles and produce GPML file of multiple VGPs.
poleLat = []
poleLon = []
poleName = []
poleInc = []
poleDec = []
poleSiteLat = []
poleSiteLon = []
poleNominalAge = []
poleA95 = []
plateID = []

count = 0

for i in xrange(0, len(plateIDs)):
    
    if raw_polesDF.Block[line[i]] == "Australia":
        
        poleLat.append(raw_polesDF.PLat[line[i]])
        poleLon.append(raw_polesDF.PLon[line[i]])
        poleName.append(raw_polesDF.Formation[line[i]])
        poleInc.append(raw_polesDF.Inc[line[i]])
        poleDec.append(raw_polesDF.Dec[line[i]])
        poleSiteLat.append(raw_polesDF.SLat[line[i]])
        poleSiteLon.append(raw_polesDF.SLon[line[i]])
        poleNominalAge.append(raw_polesDF.AgeNominal[line[i]])
        poleA95.append(raw_polesDF.a95[line[i]])
        plateID.append(plateIDs[i])

        count = count + 1
    
 
# Create new GPlates Feature Collection
vpgFeatureCollection = pgp.FeatureCollection()
    
# Create new GPlates feature 'VirtualGeomagneticPole'.
# Pole lat, pole lon, pole name, and reconstruction plate ID added within PointOnSphere method.
# Inc, Dec, A95, Age and Sample site lat/lon values to added within 'other_properties' method.

for j in xrange(0, count):

    vgpFeature = pgp.Feature.create_reconstructable_feature(
                 pgp.FeatureType.create_gpml('VirtualGeomagneticPole'),
                 pgp.PointOnSphere([np.float(poleLat[j]), np.float(poleLon[j])]),
                 name = poleName[j],
                 reconstruction_plate_id = plateID[j],
                 #valid_time=(np.float(poleAgeUpperLimit), np.float(poleAgeLowerLimit)),
                 other_properties = [(pgp.PropertyName.create_gpml('averageInclination'), pgp.XsDouble(poleInc[j])),
                                     (pgp.PropertyName.create_gpml('averageDeclination'), pgp.XsDouble(poleDec[j])),
                                     (pgp.PropertyName.create_gpml('poleA95'), pgp.XsDouble(poleA95[j])),
                                     (pgp.PropertyName.create_gpml('averageAge'), pgp.XsDouble(poleNominalAge[j])),
                                     (pgp.PropertyName.create_gpml('averageSampleSitePosition'),
                                      pgp.GmlPoint(pgp.PointOnSphere([np.float(poleSiteLat[j]), 
                                                                      np.float(poleSiteLon[j])])))])

    # Add newly created feature to existing Feature Collection
    vpgFeatureCollection.add(vgpFeature)
    
print "VGP Features created"
# Out:
# VGP Features created

# %% [markdown]
# ### Generate GPML file

# %%
# Generate GPML output file
gpmlOutputFile = "PmagPoles.gpml"

# Check for existing output directory and create it if not found
if not os.path.exists("output"):
    os.makedirs("output")

# Check for existing output file with same name and remove if found
if os.path.isfile("output/" + str(gpmlOutputFile)):
    os.remove("output/" + str(gpmlOutputFile))

# Check to make sure vgpFeatureCollection (feature collection) is not empty before writing to file
if len(vpgFeatureCollection) != 0:
    outputFeatureCollection = pgp.FeatureCollectionFileFormatRegistry()
    outputFeatureCollection.write(vpgFeatureCollection, "output/" + str(gpmlOutputFile))

# Check if new file was created and confirm export
if os.path.isfile("output/" + str(gpmlOutputFile)):
    print "Palaeomagnetic pole data successfully exported in GPML format"
